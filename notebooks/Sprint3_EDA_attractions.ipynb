# %% [markdown]
# # Sprint 3 Final Data Collection, Cleaning, and EDA for Attractions
# ---

# %%
# import relevant packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Table of Contents
# - Data Dictionary
# - Updated Data Collection
# - Updated Data Cleaning
#     - Filter Columns
#     - Drop last Row with Nulls
#     - Rating and Review Data Type Conversion
#     - Reduce Unique Values and One-Hot-Encode Main Category
# - Update Exploratory Data Analysis
#
# ---

# %% [markdown]
# ## Data Dictionary
# |Column Name| Description|
# |---|---|
# |`place_id`|generated identification made by Google Maps Extractor|
# |`name`|name of attraction|
# |`description`|details of description as seen on Google Maps|
# |`reviews`|number of reviews for attraction|
# |`competitors`|similiar attractions by Google Caps|
# |`website`|link to attraction website|
# |`phone`|phone number of attraction|
# |`can_claim`|???|
# |`owner_name`|owner of attraction|
# |`owner_profile_link`|link to owner of attraction|
# |`featured_image`|image displayed on google map|
# |`main_category`|main category assigned to attraction by Google Maps|
# |`categories`|categories assigned to attraction by Google Maps|
# |`rating`|average rating of attraction|
# |`workday_timing`|operating hours of attraction|
# |`is_temporarily_closed`|???|
# |`closed_on`|closing day(s) of attraction by Google Maps|
# |`address`|address of attraction|
# |`review_keywords`|frequent words in review for attractions by Google Maps|
# |`link`|link to google map about attraction|
# |`query`|user input on search engine of Google Maps Extractor|

# %% [markdown]
# ## Updated Data Collection

# %%
# load and view vancouver attractions data
# NOTE: the data is a combination of smaller csv files across multiple queries
# duplicates were removed via Google Sheets
df_van_attractions = pd.read_csv("merged_attractions_v2_no_duplicates.csv", index_col = 0)
df_van_attractions
# Out:
#                                                         name  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw              Langley Farm Market
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                Kin's Farm Market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                Marine Way Market
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                     Hop On Farms
# ChIJzwhBgwh3hlQRtUuytlsraag  Burnaby Artisan Farmers' Market
# ...                                                      ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                     Pandora Park
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                 John Lawson Pier
# ChIJYZRldiFyhlQRKAwf2_XOZcc         Ceperley Park Playground
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                  Devonshire Park
#                                                         NaN
#
#                                                                    description  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                                                NaN
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                                NaN
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                                NaN
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Open in limited capacity during Pop up sales a...
# ChIJzwhBgwh3hlQRtUuytlsraag  Vendors sell fresh fruit & handmade wares at t...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc                                                NaN
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#                                                                           NaN
#
#                              is_spending_on_ads  reviews  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 NaN   1489.0
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                 NaN    157.0
# ChIJRYS9gwJ3hlQRhD73njNeHfY                 NaN   2178.0
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                 NaN    153.0
# ChIJzwhBgwh3hlQRtUuytlsraag                 NaN    296.0
# ...                                         ...      ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                 NaN    637.0
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                 NaN     16.0
# ChIJYZRldiFyhlQRKAwf2_XOZcc                 NaN    292.0
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                 NaN     72.0
#                                            NaN      NaN
#
#                                                                    competitors  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  Name: Fort Langley Village Farmers' Market\nLi...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  Name: Langley Farm Market\nLink: https://www.g...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  Name: Marine Gateway\nLink: https://www.google...
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Name: Kin's Farm Market\nLink: https://www.goo...
# ChIJzwhBgwh3hlQRtUuytlsraag  Name: Kin's Farm Market\nLink: https://www.goo...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  Name: Woodland Park\nLink: https://www.google....
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg  Name: John Lawson Park | West Vancouver\nLink:...
# ChIJYZRldiFyhlQRKAwf2_XOZcc  Name: W.C. Shelly Park\nLink: https://www.goog...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  Name: Gordon Park\nLink: https://www.google.co...
#                                                                           NaN
#
#                                                                        website  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                        https://www.langleyfarm.ca/
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                     http://www.kinsfarmmarket.com/
# ChIJRYS9gwJ3hlQRhD73njNeHfY          https://www.facebook.com/MarineWayMarket/
# ChIJgzxRoT12hlQRdhSdCsG_S-Q               https://www.facebook.com/HopOnFarms/
# ChIJzwhBgwh3hlQRtUuytlsraag  http://www.artisanmarkets.ca/our-markets/burna...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc  http://vancouver.ca/parks-recreation-culture/s...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#                                                                           NaN
#
#                                       phone  can_claim  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  (604) 521-2883        1.0
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  (604) 432-6199        NaN
# ChIJRYS9gwJ3hlQRhD73njNeHfY  (604) 713-6450        1.0
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  (604) 433-9850        NaN
# ChIJzwhBgwh3hlQRtUuytlsraag  (604) 357-4736        NaN
# ...                                     ...        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  (604) 873-7000        1.0
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg             NaN        1.0
# ChIJYZRldiFyhlQRKAwf2_XOZcc  (604) 873-7000        1.0
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  (604) 873-7000        1.0
#                                        NaN        NaN
#
#                                                           owner_name  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw              Langley Farm Market (Owner)
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                Kin's Farm Market (Owner)
# ChIJRYS9gwJ3hlQRhD73njNeHfY                Marine Way Market (Owner)
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                     Hop On Farms (Owner)
# ChIJzwhBgwh3hlQRtUuytlsraag  Burnaby Artisan Farmers' Market (Owner)
# ...                                                              ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                     Pandora Park (Owner)
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                 John Lawson Pier (Owner)
# ChIJYZRldiFyhlQRKAwf2_XOZcc         Ceperley Park Playground (Owner)
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                  Devonshire Park (Owner)
#                                                                 NaN
#
#                                                             owner_profile_link  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                                                NaN
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  https://www.google.com/maps/contrib/1077249978...
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                                NaN
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  https://www.google.com/maps/contrib/1156059692...
# ChIJzwhBgwh3hlQRtUuytlsraag  https://www.google.com/maps/contrib/1027288109...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc                                                NaN
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#                                                                           NaN
#
#                              ...       main_category  \
# place_id                     ...
# ChIJoQQNT9B3hlQRwbziEuOD0zw  ...      Produce market
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  ...      Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY  ...       Shopping mall
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  ...      Produce market
# ChIJzwhBgwh3hlQRtUuytlsraag  ...     Farmers' market
# ...                          ...                 ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  ...                Park
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg  ...  Tourist attraction
# ChIJYZRldiFyhlQRKAwf2_XOZcc  ...          Playground
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  ...                Park
#                             ...                 NaN
#
#                                                                  categories  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                     Produce market, Supermarket
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                  Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                   Shopping mall
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Produce market, Farmers' market, Garden center
# ChIJzwhBgwh3hlQRtUuytlsraag                                 Farmers' market
# ...                                                                     ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                        Park, Tourist attraction
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                              Tourist attraction
# ChIJYZRldiFyhlQRKAwf2_XOZcc            Playground, Park, Tourist attraction
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                        Park, Tourist attraction
#                                                                        NaN
#
#                             rating    workday_timing is_temporarily_closed  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw    4.5  8:30 a.m.-9 p.m.                   1.0
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA    4.2     8 a.m.-7 p.m.                   1.0
# ChIJRYS9gwJ3hlQRhD73njNeHfY    4.3               NaN                   NaN
# ChIJgzxRoT12hlQRdhSdCsG_S-Q    4.7               NaN                   NaN
# ChIJzwhBgwh3hlQRtUuytlsraag    4.3     9 a.m.-2 p.m.                   1.0
# ...                            ...               ...                   ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I    4.4    6 a.m.-10 p.m.                   NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg    4.7     Open 24 hours                   NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc    4.5    6 a.m.-10 p.m.                   NaN
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8    4.2    6 a.m.-10 p.m.                   NaN
#                               NaN               NaN                   NaN
#
#                                                                      closed_on  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                                      Open All Days
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                      Open All Days
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                      Open All Days
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                                      Open All Days
# ChIJzwhBgwh3hlQRtUuytlsraag  Monday, Tuesday, Wednesday, Thursday, Friday, ...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                      Open All Days
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                      Open All Days
# ChIJYZRldiFyhlQRKAwf2_XOZcc                                      Open All Days
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                      Open All Days
#                                                                           NaN
#
#                                                                        address  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 7815 Kingsway, Burnaby, BC V3N 3E4
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  7515, 200 Market Crossing #200, Burnaby, BC V5...
# ChIJRYS9gwJ3hlQRhD73njNeHfY               Market Crossing, Burnaby, BC V5J 3J3
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                5624 Marine Dr, Burnaby, BC V5J 3G8
# ChIJzwhBgwh3hlQRtUuytlsraag                4949 Canada Wy, Burnaby, BC V5G 4A3
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I            2325 Franklin St, Vancouver, BC V5L 1S2
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                 West Vancouver, BC
# ChIJYZRldiFyhlQRKAwf2_XOZcc        8701 Stanley Park Dr, Vancouver, BC V6G 3E2
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8    1250 Devonshire Crescent, Vancouver, BC V6H 2G2
#                                                                           NaN
#
#                                                                review_keywords  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  fresh, meat, parking, deli, local, cashiers, b...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  prices, quality, deals, mall, clean, parking, ...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  parking, groceries, strip mall, choices, coffe...
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  flowers, eggs, spring, local produce, fall, gr...
# ChIJzwhBgwh3hlQRtUuytlsraag  vendors, local, music, parking, baked goods, s...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  tennis courts, community garden, basketball co...
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                             sunset
# ChIJYZRldiFyhlQRKAwf2_XOZcc  beach, fire truck, swings, beauty, age, struct...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  trees, benches, walking, picnic, atmosphere, p...
#                                                                           NaN
#
#                                                                           link  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  https://www.google.com/maps/place/Langley+Farm...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  https://www.google.com/maps/place/Kin%27s+Farm...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  https://www.google.com/maps/place/Marine+Way+M...
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  https://www.google.com/maps/place/Hop+On+Farms...
# ChIJzwhBgwh3hlQRtUuytlsraag  https://www.google.com/maps/place/Burnaby+Arti...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  https://www.google.com/maps/place/Pandora+Park...
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg  https://www.google.com/maps/place/John+Lawson+...
# ChIJYZRldiFyhlQRKAwf2_XOZcc  https://www.google.com/maps/place/Ceperley+Par...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  https://www.google.com/maps/place/Devonshire+P...
#                                                                           NaN
#
#                                                            query
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  burnaby bc food markets attractions
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  burnaby bc food markets attractions
# ChIJRYS9gwJ3hlQRhD73njNeHfY  burnaby bc food markets attractions
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  burnaby bc food markets attractions
# ChIJzwhBgwh3hlQRtUuytlsraag  burnaby bc food markets attractions
# ...                                                          ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I     tourist attractions vancouver bc
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg     tourist attractions vancouver bc
# ChIJYZRldiFyhlQRKAwf2_XOZcc     tourist attractions vancouver bc
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8     tourist attractions vancouver bc
#                                                             NaN
#
# [962 rows x 21 columns]

# %% [markdown]
# TASK: Find high-level information about this dataset such as:
# 1. Data shape and size
# 2. Column names
# 3. Data types

# %%
# check for data shape and size
print(f'The Vancouver tourist attractions dataset consists of {df_van_attractions.shape[0]} rows and {df_van_attractions.shape[1]} columns.')
print(f'The dataset consists of {df_van_attractions.size} elements.')
# Out:
# The Vancouver tourist attractions dataset consists of 962 rows and 21 columns.
# The dataset consists of 20202 elements.

# %%
# check column names
df_van_attractions.columns
# Out:
# Index(['name', 'description', 'is_spending_on_ads', 'reviews', 'competitors',
#        'website', 'phone', 'can_claim', 'owner_name', 'owner_profile_link',
#        'featured_image', 'main_category', 'categories', 'rating',
#        'workday_timing', 'is_temporarily_closed', 'closed_on', 'address',
#        'review_keywords', 'link', 'query'],
#       dtype='object')

# %%
# check for data types
df_van_attractions.dtypes
# Out:
# name                      object
# description               object
# is_spending_on_ads       float64
# reviews                  float64
# competitors               object
# website                   object
# phone                     object
# can_claim                float64
# owner_name                object
# owner_profile_link        object
# featured_image            object
# main_category             object
# categories                object
# rating                   float64
# workday_timing            object
# is_temporarily_closed    float64
# closed_on                 object
# address                   object
# review_keywords           object
# link                      object
# query                     object
# dtype: object

# %% [markdown]
# **Data Collection Findings**
#
# There are 962 row and 21 columns. All columns are set to object data type due to merging multiple csv file. Duplicate data was removed through Google Sheets. Not all columns will be used in the csv file.
#
# The following columns will be used for the upcoming recommendation system model
# - name
# - description
# - reviews
# - website
# - main_category
# - categories
# - rating
# - address
# - review_keywords
#
# The following columns will be converted be changed to float64 or int64 for EDA: rating, reviews
#
# ---
#
# ## Updated Data Cleaning
#
# ### Filter Columns

# %%
# filter columns for upcoming model
df_van_attractions = df_van_attractions[['name','description','reviews','website','main_category','categories','rating','address','review_keywords']]
df_van_attractions
# Out:
#                                                         name  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw              Langley Farm Market
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                Kin's Farm Market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                Marine Way Market
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                     Hop On Farms
# ChIJzwhBgwh3hlQRtUuytlsraag  Burnaby Artisan Farmers' Market
# ...                                                      ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                     Pandora Park
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                 John Lawson Pier
# ChIJYZRldiFyhlQRKAwf2_XOZcc         Ceperley Park Playground
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                  Devonshire Park
#                                                         NaN
#
#                                                                    description  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                                                NaN
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                                NaN
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                                NaN
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Open in limited capacity during Pop up sales a...
# ChIJzwhBgwh3hlQRtUuytlsraag  Vendors sell fresh fruit & handmade wares at t...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc                                                NaN
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#                                                                           NaN
#
#                              reviews  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw   1489.0
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA    157.0
# ChIJRYS9gwJ3hlQRhD73njNeHfY   2178.0
# ChIJgzxRoT12hlQRdhSdCsG_S-Q    153.0
# ChIJzwhBgwh3hlQRtUuytlsraag    296.0
# ...                              ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I    637.0
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg     16.0
# ChIJYZRldiFyhlQRKAwf2_XOZcc    292.0
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8     72.0
#                                 NaN
#
#                                                                        website  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                        https://www.langleyfarm.ca/
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                     http://www.kinsfarmmarket.com/
# ChIJRYS9gwJ3hlQRhD73njNeHfY          https://www.facebook.com/MarineWayMarket/
# ChIJgzxRoT12hlQRdhSdCsG_S-Q               https://www.facebook.com/HopOnFarms/
# ChIJzwhBgwh3hlQRtUuytlsraag  http://www.artisanmarkets.ca/our-markets/burna...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc  http://vancouver.ca/parks-recreation-culture/s...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#                                                                           NaN
#
#                                   main_category  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw      Produce market
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA      Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY       Shopping mall
# ChIJgzxRoT12hlQRdhSdCsG_S-Q      Produce market
# ChIJzwhBgwh3hlQRtUuytlsraag     Farmers' market
# ...                                         ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                Park
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg  Tourist attraction
# ChIJYZRldiFyhlQRKAwf2_XOZcc          Playground
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                Park
#                                            NaN
#
#                                                                  categories  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                     Produce market, Supermarket
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                  Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                   Shopping mall
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Produce market, Farmers' market, Garden center
# ChIJzwhBgwh3hlQRtUuytlsraag                                 Farmers' market
# ...                                                                     ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                        Park, Tourist attraction
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                              Tourist attraction
# ChIJYZRldiFyhlQRKAwf2_XOZcc            Playground, Park, Tourist attraction
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                        Park, Tourist attraction
#                                                                        NaN
#
#                              rating  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw     4.5
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA     4.2
# ChIJRYS9gwJ3hlQRhD73njNeHfY     4.3
# ChIJgzxRoT12hlQRdhSdCsG_S-Q     4.7
# ChIJzwhBgwh3hlQRtUuytlsraag     4.3
# ...                             ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I     4.4
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg     4.7
# ChIJYZRldiFyhlQRKAwf2_XOZcc     4.5
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8     4.2
#                                NaN
#
#                                                                        address  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 7815 Kingsway, Burnaby, BC V3N 3E4
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  7515, 200 Market Crossing #200, Burnaby, BC V5...
# ChIJRYS9gwJ3hlQRhD73njNeHfY               Market Crossing, Burnaby, BC V5J 3J3
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                5624 Marine Dr, Burnaby, BC V5J 3G8
# ChIJzwhBgwh3hlQRtUuytlsraag                4949 Canada Wy, Burnaby, BC V5G 4A3
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I            2325 Franklin St, Vancouver, BC V5L 1S2
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                 West Vancouver, BC
# ChIJYZRldiFyhlQRKAwf2_XOZcc        8701 Stanley Park Dr, Vancouver, BC V6G 3E2
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8    1250 Devonshire Crescent, Vancouver, BC V6H 2G2
#                                                                           NaN
#
#                                                                review_keywords
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  fresh, meat, parking, deli, local, cashiers, b...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  prices, quality, deals, mall, clean, parking, ...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  parking, groceries, strip mall, choices, coffe...
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  flowers, eggs, spring, local produce, fall, gr...
# ChIJzwhBgwh3hlQRtUuytlsraag  vendors, local, music, parking, baked goods, s...
# ...                                                                        ...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  tennis courts, community garden, basketball co...
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                             sunset
# ChIJYZRldiFyhlQRKAwf2_XOZcc  beach, fire truck, swings, beauty, age, struct...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  trees, benches, walking, picnic, atmosphere, p...
#                                                                           NaN
#
# [962 rows x 9 columns]

# %% [markdown]
# ### Drop Last Row with Nulls

# %%
# drop null last row
df_van_attractions = df_van_attractions[:-1]

# %% [markdown]
# ### Rating and Review Data Type Conversion

# %%
# convert reviews and rating in df_van_attractions to int64
df_van_attractions = df_van_attractions.astype({'reviews': int, 'rating': float})
df_van_attractions.dtypes
# Out:
# name                object
# description         object
# reviews              int32
# website             object
# main_category       object
# categories          object
# rating             float64
# address             object
# review_keywords     object
# dtype: object

# %% [markdown]
# ### Reduce Unique Values and One-Hot-Encode Main Category

# %%
# Check the current number of unique values in Main Category
# plot distribution of current values in main_category column 
plt.figure(figsize=(33,3))
plt.title('Distribution of Main Categories for Metro Vancouver Attractions')
df_van_attractions['main_category'].value_counts().plot(kind='bar',color='salmon')
# sns.barplot(data=df_van_attractions, x="main_category")
plt.xlabel('main_category')
plt.ylabel('Count')
plt.show()

# %%
# top 4 main_categories of attractions
df_van_attractions['main_category'].value_counts().head(4)
# Out:
# main_category
# Park                  219
# Tourist attraction     83
# Shopping mall          81
# Restaurant             56
# Name: count, dtype: int64

# %% [markdown]
# From the main_category, there are 161 unique values. Modify the main_cateogry to take the top 4 values and make the rest into an 'other' category. One-Hot Encode the top 4 main categories and drop the other column. The reason for main category modification is easier interpretability in EDA.

# %%
# Modify the Number of Unique Values in Main Category
# Get list of top 4 frequent categories
top_categories = ['Park','Tourist attraction', 'Shopping mall','Restaurant']

# Replace all other categories with 'Other'
df_van_attractions['main_category'] = df_van_attractions['main_category'].apply(lambda x: x if x in top_categories else 'Other')

# check modified main_category column in Dataframe
df_van_attractions['main_category'].value_counts()
# Out:
# main_category
# Other                 522
# Park                  219
# Tourist attraction     83
# Shopping mall          81
# Restaurant             56
# Name: count, dtype: int64

# %%
# Apply One-Hot Encoding to main_category column 
df_van_attractions_encoded = pd.get_dummies(df_van_attractions, columns=['main_category'])

# Rename multiple columns in encoded main_category
df_van_attractions_encoded.rename(columns={'main_category_Park': 'MC_park', 
                                           'main_category_Restaurant': 'MC_restaurant',
                                           'main_category_Shopping mall': 'MC_shopping',
                                           'main_category_Tourist attraction': 'MC_tourist'}, inplace=True)

# drop main_category_Other column
df_van_attractions_encoded.drop(columns=['main_category_Other'], inplace=True)

# view final modification of main_category in dataframe 
df_van_attractions_encoded.head()
# Out:
#                                                         name  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw              Langley Farm Market
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                Kin's Farm Market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                Marine Way Market
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                     Hop On Farms
# ChIJzwhBgwh3hlQRtUuytlsraag  Burnaby Artisan Farmers' Market
#
#                                                                    description  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                                                NaN
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                                NaN
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                                NaN
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Open in limited capacity during Pop up sales a...
# ChIJzwhBgwh3hlQRtUuytlsraag  Vendors sell fresh fruit & handmade wares at t...
#
#                              reviews  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw     1489
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA      157
# ChIJRYS9gwJ3hlQRhD73njNeHfY     2178
# ChIJgzxRoT12hlQRdhSdCsG_S-Q      153
# ChIJzwhBgwh3hlQRtUuytlsraag      296
#
#                                                                        website  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                        https://www.langleyfarm.ca/
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                     http://www.kinsfarmmarket.com/
# ChIJRYS9gwJ3hlQRhD73njNeHfY          https://www.facebook.com/MarineWayMarket/
# ChIJgzxRoT12hlQRdhSdCsG_S-Q               https://www.facebook.com/HopOnFarms/
# ChIJzwhBgwh3hlQRtUuytlsraag  http://www.artisanmarkets.ca/our-markets/burna...
#
#                                                                  categories  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                     Produce market, Supermarket
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                                  Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                                   Shopping mall
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  Produce market, Farmers' market, Garden center
# ChIJzwhBgwh3hlQRtUuytlsraag                                 Farmers' market
#
#                              rating  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw     4.5
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA     4.2
# ChIJRYS9gwJ3hlQRhD73njNeHfY     4.3
# ChIJgzxRoT12hlQRdhSdCsG_S-Q     4.7
# ChIJzwhBgwh3hlQRtUuytlsraag     4.3
#
#                                                                        address  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 7815 Kingsway, Burnaby, BC V3N 3E4
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  7515, 200 Market Crossing #200, Burnaby, BC V5...
# ChIJRYS9gwJ3hlQRhD73njNeHfY               Market Crossing, Burnaby, BC V5J 3J3
# ChIJgzxRoT12hlQRdhSdCsG_S-Q                5624 Marine Dr, Burnaby, BC V5J 3G8
# ChIJzwhBgwh3hlQRtUuytlsraag                4949 Canada Wy, Burnaby, BC V5G 4A3
#
#                                                                review_keywords  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  fresh, meat, parking, deli, local, cashiers, b...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  prices, quality, deals, mall, clean, parking, ...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  parking, groceries, strip mall, choices, coffe...
# ChIJgzxRoT12hlQRdhSdCsG_S-Q  flowers, eggs, spring, local produce, fall, gr...
# ChIJzwhBgwh3hlQRtUuytlsraag  vendors, local, music, parking, baked goods, s...
#
#                              MC_park  MC_restaurant  MC_shopping  MC_tourist
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw    False          False        False       False
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA    False          False        False       False
# ChIJRYS9gwJ3hlQRhD73njNeHfY    False          False         True       False
# ChIJgzxRoT12hlQRdhSdCsG_S-Q    False          False        False       False
# ChIJzwhBgwh3hlQRtUuytlsraag    False          False        False       False

# %% [markdown]
# ---
#
# ## Updated Exploratory Data Analysis
#
# - Check for Null Values
# - Check for Duplicated Columns/Rows
# - Distribution of Rating and Review Data
#     - Overall
#     - By main category (ie. MC_park, MC_restaurant,MC_shopping,MC_tourist)

# %%
# check for null values in data
df_van_attractions_encoded.isna().sum()
# Out:
# name                 0
# description        484
# reviews              0
# website            280
# categories           8
# rating               0
# address              0
# review_keywords    113
# MC_park              0
# MC_restaurant        0
# MC_shopping          0
# MC_tourist           0
# dtype: int64

# %%
# check for rows where null values are present 
null_df = df_van_attractions_encoded.isnull().any(axis=1)
null_rows = df_van_attractions_encoded[null_df]
print(null_rows)
# Out:
#                                                         name description  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw              Langley Farm Market         NaN
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                Kin's Farm Market         NaN
# ChIJRYS9gwJ3hlQRhD73njNeHfY                Marine Way Market         NaN
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8  Parkgate Farm Market Kensington         NaN
# ChIJZX60uzB4hlQROscvUCodE7s                Joe's Farm Market         NaN
# ...                                                      ...         ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8                         Ash Park         NaN
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                     Pandora Park         NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                 John Lawson Pier         NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc         Ceperley Park Playground         NaN
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                  Devonshire Park         NaN
#
#                              reviews  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw     1489
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA      157
# ChIJRYS9gwJ3hlQRhD73njNeHfY     2178
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8      203
# ChIJZX60uzB4hlQROscvUCodE7s      124
# ...                              ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8      211
# ChIJEWq_7hhxhlQR_k-jUi4iX1I      637
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg       16
# ChIJYZRldiFyhlQRKAwf2_XOZcc      292
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8       72
#
#                                                                        website  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                        https://www.langleyfarm.ca/
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                     http://www.kinsfarmmarket.com/
# ChIJRYS9gwJ3hlQRhD73njNeHfY          https://www.facebook.com/MarineWayMarket/
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8                https://m.facebook.com/parkgatebby/
# ChIJZX60uzB4hlQROscvUCodE7s                                                NaN
# ...                                                                        ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8  https://covapp.vancouver.ca/parkfinder/ParkDet...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                                                NaN
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                                NaN
# ChIJYZRldiFyhlQRKAwf2_XOZcc  http://vancouver.ca/parks-recreation-culture/s...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                                                NaN
#
#                                                              categories  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 Produce market, Supermarket
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA                              Produce market
# ChIJRYS9gwJ3hlQRhD73njNeHfY                               Shopping mall
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8  Farmers' market, Fruit and vegetable store
# ChIJZX60uzB4hlQROscvUCodE7s                              Produce market
# ...                                                                 ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8                    Park, Tourist attraction
# ChIJEWq_7hhxhlQR_k-jUi4iX1I                    Park, Tourist attraction
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                          Tourist attraction
# ChIJYZRldiFyhlQRKAwf2_XOZcc        Playground, Park, Tourist attraction
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8                    Park, Tourist attraction
#
#                              rating  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw     4.5
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA     4.2
# ChIJRYS9gwJ3hlQRhD73njNeHfY     4.3
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8     4.5
# ChIJZX60uzB4hlQROscvUCodE7s     4.2
# ...                             ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8     4.3
# ChIJEWq_7hhxhlQR_k-jUi4iX1I     4.4
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg     4.7
# ChIJYZRldiFyhlQRKAwf2_XOZcc     4.5
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8     4.2
#
#                                                                        address  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw                 7815 Kingsway, Burnaby, BC V3N 3E4
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  7515, 200 Market Crossing #200, Burnaby, BC V5...
# ChIJRYS9gwJ3hlQRhD73njNeHfY               Market Crossing, Burnaby, BC V5J 3J3
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8              6530 Hastings St, Burnaby, BC V5B 1S2
# ChIJZX60uzB4hlQROscvUCodE7s               9612 Cameron St, Burnaby, BC V3J 1M2
# ...                                                                        ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8                 8288 Ash St, Vancouver, BC V6P 3L9
# ChIJEWq_7hhxhlQR_k-jUi4iX1I            2325 Franklin St, Vancouver, BC V5L 1S2
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                 West Vancouver, BC
# ChIJYZRldiFyhlQRKAwf2_XOZcc        8701 Stanley Park Dr, Vancouver, BC V6G 3E2
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8    1250 Devonshire Crescent, Vancouver, BC V6H 2G2
#
#                                                                review_keywords  \
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw  fresh, meat, parking, deli, local, cashiers, b...
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA  prices, quality, deals, mall, clean, parking, ...
# ChIJRYS9gwJ3hlQRhD73njNeHfY  parking, groceries, strip mall, choices, coffe...
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8  prices, groceries, quality, bread, selection, ...
# ChIJZX60uzB4hlQROscvUCodE7s  prices, quality, grocery store, asian, snacks,...
# ...                                                                        ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8  school, climbing, grass, brand, swings, chairs...
# ChIJEWq_7hhxhlQR_k-jUi4iX1I  tennis courts, community garden, basketball co...
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg                                             sunset
# ChIJYZRldiFyhlQRKAwf2_XOZcc  beach, fire truck, swings, beauty, age, struct...
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8  trees, benches, walking, picnic, atmosphere, p...
#
#                              MC_park  MC_restaurant  MC_shopping  MC_tourist
# place_id
# ChIJoQQNT9B3hlQRwbziEuOD0zw    False          False        False       False
# ChIJcRtGbQ12hlQRhbiiQ5c-KSA    False          False        False       False
# ChIJRYS9gwJ3hlQRhD73njNeHfY    False          False         True       False
# ChIJaYzamVZ3hlQR3jJgDsB8Ip8    False          False        False       False
# ChIJZX60uzB4hlQROscvUCodE7s    False          False        False       False
# ...                              ...            ...          ...         ...
# ChIJmfKAD_R0hlQR2etVxiSVvu8     True          False        False       False
# ChIJEWq_7hhxhlQR_k-jUi4iX1I     True          False        False       False
# ChIJuQ8dDy1vhlQRm4YJmRhKXeg    False          False        False        True
# ChIJYZRldiFyhlQRKAwf2_XOZcc    False          False        False       False
# ChIJ4eZqHpBzhlQRbF5hkWtQPN8     True          False        False       False
#
# [550 rows x 12 columns]

# %%
# count for duplicated rows in the dataset
len(df_van_attractions_encoded)-len(df_van_attractions_encoded.drop_duplicates())
# Out:
# 0

# %%
# plot histogram for ratings overall
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.hist(df_van_attractions_encoded['rating'],bins=30,color="salmon")
plt.title('Distribution of Customer Ratings for Vancouver Attractions')
plt.xlabel('Rating')
plt.ylabel('Frequency')
# plot histogram for number of reviews overall
plt.subplot(1,2,2)
plt.hist(df_van_attractions_encoded['reviews'],bins=50,color="salmon")
plt.title('Distribution of Number of Customer Reviews for Vancouver Attractions')
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.show()

# %%
# create new dataset for preprocessing and modelling
df_van_attractions_encoded.to_csv('new_van_attractions.csv')

# %% [markdown]
# #### Updated EDA Findings
#
# There are 550 rows of data containing null values out of the total 961 rows. The columns `description`, `website`, and `review_keywords` are where the data has null values. Since values in columns `description` and `website` won't be used in the baseline model, there is no need to replace them at this point. Those columns are meant to give additional insight to users about the attraction. The proprocessing and modelling section will handle the null values located in the `review_keywords` for attractions that have no Google Map reviews.
#
# There are no rows of duplicated data due to the 'Data cleanup' tab on Google Sheets.
#
# The distribution of updated data for rating and reviews are skewed to a certain range which could impact model evaluation. The rating for attractions is skewed left towards range of 3.5 to 5 stars out of 5. The reason for the skewed ratings can come from how the search engine for Google Maps and their own recommendation model. The number of reviews for attractions is skewed right towards 0-5000 reviews.
